# %%
# %matplotlib inline


import pandas as pd
from sklearn import linear_model
from sklearn.feature_selection import VarianceThreshold
from sklearn import tree
import math
import cmath
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import time
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-23ede8e2a5da> in <module>()
#       3
#       4 import pandas as pd
# ----> 5 from sklearn import linear_model
#       6 from sklearn.feature_selection import VarianceThreshold
#       7 from sklearn import tree
#
# /Users/alange/anaconda/lib/python3.4/site-packages/sklearn/linear_model/__init__.py in <module>()
#      13
#      14 from .bayes import BayesianRidge, ARDRegression
# ---> 15 from .least_angle import (Lars, LassoLars, lars_path, LarsCV, LassoLarsCV,
#      16                           LassoLarsIC)
#      17 from .coordinate_descent import (Lasso, ElasticNet, LassoCV, ElasticNetCV,
#
# /Users/alange/anaconda/lib/python3.4/site-packages/sklearn/linear_model/least_angle.py in <module>()
#      23 from ..base import RegressorMixin
#      24 from ..utils import arrayfuncs, as_float_array, check_X_y
# ...

# %%
df = pd.read_csv("../x.dat", header=None)
dfy = pd.read_csv("../y.dat", header=None)

# %%
dff = df.transpose()
dffy = dfy.transpose()
dff.head()
# Out:
#           0         1         2         3  4         5         6
# 0  0.000010 -0.000077  0.000066 -0.000198  0  0.000153  0.000006
# 1  0.000008 -0.000129  0.000022 -0.000236  0  0.000074 -0.000008
# 2 -0.000032 -0.000131  0.000080  0.000076  0  0.000032  0.000014
# 3  0.000006 -0.000153  0.000040 -0.000039  0 -0.000031  0.000016
# 4 -0.000019 -0.000210  0.000057 -0.000219  0 -0.000129 -0.000005

# %%
dff.plot()

# %%
dff[1].plot()

# %%
dff[2].plot()

# %%
dffy[1].plot()

# %%
32 * 3600
# Out:
# 115200

# %%
dff.plot()

# %%
dff[6][40000:50000].plot()

# %%
df1 = pd.read_csv("../x1.dat", header=None)
df2 = pd.read_csv("../x2.dat", header=None)
df3 = pd.read_csv("../x3.dat", header=None)
dff1 = df1.transpose()
dff2 = df2.transpose()
dff3 = df3.transpose()

# %%
dff1[1].plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9c3dd3c0820e> in <module>()
# ----> 1 dff1[1].plot()
#
# NameError: name 'dff1' is not defined

# %%
dff2[1].plot()

# %%
dff3[1].plot()

# %%
n = 2
p = (dff1[n] * dff2[n] * dff3[n]) * 10**6
p.plot()

# %%
p.sum()
# Out:
# 0.00018534241291480978

# %%
n = 6
print(((dff1[n] * dff2[n])**0.5).sum())
print(((dff1[n] * dff3[n])**0.5).sum())
print(((dff2[n] * dff3[n])**0.5).sum())
print(((dff1[n] * dff2[n] * dff3[n])**(1.0/3.0)).sum())
# Out:
# 0.29246046429
# 0.288080176797
# 0.280142412985
# 0.281062494254

# %%
dfb = pd.read_csv("../bbar_4_bar_1280.csv", header=None)

# %%
dfb[6]
# Out:
# 0    0.000194
# 1    0.000249
# 2    0.000190
# 3    0.001329
# 4    0.000000
# 5    0.000161
# 6    0.000518
# Name: 6, dtype: float64

# %%
dfb.ix[:,9:(8+3600)]
# Out:
#        9         10        11        12        13            14        15    \
# 0  0.000086  0.000017 -0.000014 -0.000008 -0.000011 -7.240205e-08  0.000032
# 1 -0.000080 -0.000114 -0.000136 -0.000160 -0.000183 -1.677070e-04 -0.000134
# 2  0.000110  0.000056  0.000058  0.000050  0.000049  4.356797e-05  0.000061
# 3  0.000070 -0.000099 -0.000038 -0.000071 -0.000172 -2.264467e-04 -0.000260
# 4  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000e+00  0.000000
# 5  0.000075  0.000070  0.000026 -0.000037 -0.000095 -1.000333e-04 -0.000074
# 6  0.000423  0.000077  0.000008  0.000010  0.000008  2.241451e-05  0.000047
#
#        16        17        18      ...         3599      3600          3601  \
# 0  0.000034  0.000077  0.000137    ...     0.000093  0.000026 -2.792143e-06
# 1 -0.000096 -0.000026  0.000071    ...     0.000363  0.000226  9.953982e-05
# 2  0.000070  0.000085  0.000114    ...     0.000090  0.000024 -3.938993e-07
# ...

# %%
n = 1
ch1 = pd.Series.tolist(dfb.ix[n,(9+0*3600):(8+1*3600)])
ch1d1 = pd.Series.tolist(dfb.ix[n,(9+1*3600):(8+2*3600)])
ch2 = pd.Series.tolist(dfb.ix[n,(9+2*3600):(8+3*3600)])
ch2d1 = pd.Series.tolist(dfb.ix[n,(9+3*3600):(8+4*3600)])

# %%
plt.plot(ch2[2600:2700])

# %%
plt.plot(ch2d1[2600:2700])

# %%
plt.plot(ch1d2[-100:])

# %%
from scipy.fftpack import fft, ifft

# %%
ch2_fft = fft(ch2)

# %%
plt.plot(np.abs(ch2_fft[:1800]))

# %%
ch2_fft_adj = [x if np.abs(x) > 0.06 else 0.0j for x in ch2_fft]

# %%
ch2_fft_adj = [x if i > 200 else 0.0j for i, x in enumerate(ch2_fft)]

# %%
ch2_adj = ifft(ch2_fft_adj)

# %%
plt.plot(ch2[2600:2700])
plt.plot(ch2_adj[2600:2700])
# Out:
# /Users/alange/anaconda/lib/python3.4/site-packages/numpy/core/numeric.py:462: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.plot(ch2[-500:])
plt.plot(ch2_adj[-500:])
# Out:
# /Users/alange/anaconda/lib/python3.4/site-packages/numpy/core/numeric.py:462: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.plot((ch2 - ch2_adj))
# Out:
# /Users/alange/anaconda/lib/python3.4/site-packages/numpy/core/numeric.py:462: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
pd.Series(ch1).describe()
# Out:
# count    3.600000e+03
# mean    -1.776357e-17
# std      4.027248e-04
# min     -2.502334e-03
# 25%     -2.376394e-04
# 50%      7.375795e-07
# 75%      2.540845e-04
# max      1.614373e-03
# dtype: float64

# %%
std1 = 4.027248e-04
std2 = 2.492199e-04

std = std1
ch1_trim = [x if abs(x) > 3*std else 0.0 for x in ch1]
# plt.plot(ch1[:])
plt.plot(ch1_trim[:])

# %%
ch1_trim_fft = fft(ch1_trim)
plt.plot(np.abs(ch1_trim_fft[:1800]))

# %%
# DFT implementation
# y(j) = sum[k=0..n-1] x[k] * exp(-sqrt(-1)*j*k*2*pi/n)
# j = 0..n-1

def dft(x):
    n = len(x)
    two_pi_over_n = (2 * math.pi / n)
    y = []
    for j in range(n//2):  # by symmetry, only need first half
        j_two_pi_over_n = j * two_pi_over_n * 1.0j
        y.append(sum([x[k] * cmath.exp(-j_two_pi_over_n * k) for k in range(n)]))
    return y

def dft_power(x, n_j=None):
    n = len(x)
    if n_j is None:
        n_j = n // 2
    two_pi_over_n = (2 * math.pi / n)
    y = []
    for j in range(n_j):
        j_two_pi_over_n = j * two_pi_over_n
        yj_re = 0.0
        yj_im = 0.0
        for k in range(n):
            z = j_two_pi_over_n * k
            yj_re += x[k] * math.cos(z)
            yj_im += x[k] * math.sin(-z)
        y.append((yj_re, yj_im))
    return [math.sqrt(re*re + im*im) for re, im in y]

# %%
zzz = dft(ch2)

# %%
ch2_fft[:5]
# Out:
# array([ -1.52766797e-13+0.j        ,  -1.16401627e-02-0.0976479j ,
#          2.18542373e-02+0.00240074j,   1.07691352e-02+0.09314874j,
#          2.63797941e-02+0.01031739j])

# %%
zzz[:5]
# Out:
# [(-1.5273296272459366e-13+0j),
#  (-0.011640162655495546-0.097647901677910473j),
#  (0.021854237325063412+0.0024007415024379242j),
#  (0.010769135180088225+0.093148735021654591j),
#  (0.026379794069927437+0.010317393863133021j)]

# %%
plt.plot(np.abs(zzz))

# %%
ts = time.time()
dft_power(ch2, 500)
print(time.time() - ts)
# Out:
# 1.1643249988555908
